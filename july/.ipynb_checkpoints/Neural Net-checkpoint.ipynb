# %% [markdown]
# # Libraries Import

# %%
import numpy as np
import torch
import torch.nn as nn


from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics.regression import mean_absolute_error as mae
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Data

# %%
filename = "./data/varyHitI_2000.txt"
data = np.loadtxt(filename)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-b6c65989edad> in <module>
#       1 filename = "./data/varyHitI_2000.txt"
# ----> 2 data = np.loadtxt(filename)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
#     265     ds = DataSource(destpath)
# --> 266     return ds.open(path, mode, encoding=encoding, newline=newline)
#     267
#     268
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     622                                       encoding=encoding, newline=newline)
#     623         else:
# --> 624             raise IOError("%s not found." % path)
#     625
#     626
#
# OSError: ./data/varyHitI_2000.txt not found.

# %%
y = data[:, 0].reshape(-1, 1)
X = data[:, 1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ea1053d3b819> in <module>
# ----> 1 y = data[:, 0].reshape(-1, 1)
#       2 X = data[:, 1:]
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Neural Network

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device:', device)
# Out:
# device: cpu

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.fc1 = nn.Linear(400,2048)
        self.fc2 = nn.Linear(2048,2048)
        self.fc3 = nn.Linear(2048,2048)

        self.out = nn.Linear(2048, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))

        x = self.out(x)
        return x

# %%
def train(net, train_loader, X_test, y_test, learning_rate=1e-3, num_epochs=200):
    # L1 loss i.e MAE
    criterion = nn.L1Loss()
    optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)
    net.to(device)

    losses = []
    maes = []

    for epoch in range(num_epochs):
        net.train()
    for i_batch, data in enumerate(train_loader, 0):
        X, Y = data
        X = X.to(device)
        Y = Y.to(device)

        optimizer.zero_grad()
        out = net(X)

        loss = criterion(out, Y)
        loss.backward()
        optimizer.step()

    if (epoch+1) % 10 == 0:
        with torch.no_grad():
            y_pred_test = net(X_test)
            cur_mae = mae(y_pred_test.cpu(), y_test)
            maes.append(cur_mae)

    losses.append(loss.item())

    return (losses, maes)
# Out:
#   File "<ipython-input-14-d7e1ec835c94>", line 11
#     net.train()
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# ## Result

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f1d2b9ea0846> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
#
# NameError: name 'X' is not defined

# %%
net = Net()

# %%
train_loader = DataLoader(dataset, batch_size=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fad634413d0d> in <module>
# ----> 1 train_loader = DataLoader(dataset, batch_size=200)
#
# NameError: name 'dataset' is not defined

# %%
losses, maes = train(net, train_loader, X_test, y_test, \
                     learning_rate=1e-3, num_epochs=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-72fd498a1d80> in <module>
# ----> 1 losses, maes = train(net, train_loader, X_test, y_test, \
#       2                      learning_rate=1e-3, num_epochs=200)
#
# NameError: name 'train' is not defined

# %%
plt.plot(range(len(losses)), losses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b0b1b4c11f34> in <module>
# ----> 1 plt.plot(range(len(losses)), losses)
#
# NameError: name 'plt' is not defined

# %%
print('best mae:', np.min(maes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-53d8abe58e3a> in <module>
# ----> 1 print('best mae:', np.min(maes))
#
# NameError: name 'maes' is not defined
